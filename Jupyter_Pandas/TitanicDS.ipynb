# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as pp

# %%
np.random.seed(42)

# %%
X, y = fetch_openml("titanic", version=1, as_frame=True, return_X_y=True)
X.drop(['boat', 'body', 'home.dest'], axis=1, inplace=True)
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train.head(9).sort_index()
# Out:
#       pclass                                           name     sex   age  \
# 25       1.0                            Birnbaum, Mr. Jakob    male  25.0
# 196      1.0                           Marechal, Mr. Pierre    male   NaN
# 392      2.0  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0
# 604      3.0                    Abelseth, Miss. Karen Marie  female  16.0
# 605      3.0                  Abelseth, Mr. Olaus Jorgensen    male  25.0
# 628      3.0              Andersson, Miss. Sigrid Elisabeth  female  11.0
# 999      3.0              McCarthy, Miss. Catherine 'Katie'  female   NaN
# 1165     3.0                               Saad, Mr. Khalil    male  25.0
# 1278     3.0                         Vendel, Mr. Olof Edvin    male  20.0
#
#       sibsp  parch         ticket     fare  cabin embarked
# 25      0.0    0.0          13905  26.0000   None        C
# 196     0.0    0.0          11774  29.7000    C47        C
# 392     1.0    0.0  SC/PARIS 2167  27.7208   None        C
# 604     0.0    0.0         348125   7.6500   None        S
# 605     0.0    0.0         348122   7.6500  F G63        S
# 628     4.0    2.0         347082  31.2750   None        S
# 999     0.0    0.0         383123   7.7500   None        Q
# 1165    0.0    0.0           2672   7.2250   None        C
# 1278    0.0    0.0         350416   7.8542   None        S

# %%
X_train.isnull().sum()
# Out:
# pclass        0
# name          0
# sex           0
# age         209
# sibsp         0
# parch         0
# ticket        0
# fare          1
# cabin       822
# embarked      0
# dtype: int64

# %%
X_train.cov()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10764\2686870505.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   X_train.cov()
#            pclass         age     sibsp      parch         fare
# pclass   0.691795   -4.724047  0.036028  -0.002820   -23.512594
# age     -4.724047  206.288195 -3.512146  -2.128722   113.837441
# sibsp    0.036028   -3.512146  1.020545   0.334959     9.060703
# parch   -0.002820   -2.128722  0.334959   0.743892    10.298036
# fare   -23.512594  113.837441  9.060703  10.298036  2392.757409

# %%
X_train.isnull().sum() / len(X_train) * 100
# Out:
# pclass       0.000000
# name         0.000000
# sex          0.000000
# age         19.961796
# sibsp        0.000000
# parch        0.000000
# ticket       0.000000
# fare         0.095511
# cabin       78.510029
# embarked     0.000000
# dtype: float64

# %%
X_train.head()
# Out:
#       pclass                                           name     sex   age  \
# 999      3.0              McCarthy, Miss. Catherine 'Katie'  female   NaN
# 392      2.0  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0
# 628      3.0              Andersson, Miss. Sigrid Elisabeth  female  11.0
# 1165     3.0                               Saad, Mr. Khalil    male  25.0
# 604      3.0                    Abelseth, Miss. Karen Marie  female  16.0
#
#       sibsp  parch         ticket     fare cabin embarked
# 999     0.0    0.0         383123   7.7500  None        Q
# 392     1.0    0.0  SC/PARIS 2167  27.7208  None        C
# 628     4.0    2.0         347082  31.2750  None        S
# 1165    0.0    0.0           2672   7.2250  None        C
# 604     0.0    0.0         348125   7.6500  None        S

# %%
X_train.drop(['cabin'],axis=1,inplace=True)

# %%
X_train.head()
# Out:
#       pclass                                           name     sex   age  \
# 999      3.0              McCarthy, Miss. Catherine 'Katie'  female   NaN
# 392      2.0  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0
# 628      3.0              Andersson, Miss. Sigrid Elisabeth  female  11.0
# 1165     3.0                               Saad, Mr. Khalil    male  25.0
# 604      3.0                    Abelseth, Miss. Karen Marie  female  16.0
#
#       sibsp  parch         ticket     fare embarked
# 999     0.0    0.0         383123   7.7500        Q
# 392     1.0    0.0  SC/PARIS 2167  27.7208        C
# 628     4.0    2.0         347082  31.2750        S
# 1165    0.0    0.0           2672   7.2250        C
# 604     0.0    0.0         348125   7.6500        S

# %%
X_train['family_size']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\MLStats\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'family_size'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [44], line 1
# ----> 1 X_train['family_size']
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\pandas\core\frame.py:3805, in DataFrame.__getitem__(self, key)
#    3803 if self.columns.nlevels > 1:
#    3804     return self._getitem_multilevel(key)
# -> 3805 indexer = self.columns.get_loc(key)
#    3806 if is_integer(indexer):
#    3807     indexer = [indexer]
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#    3810     self._check_indexing_error(key)
#
# KeyError: 'family_size'

# %%
X_train.sort_index()
# Out:
#       pclass                                             name     sex  \
# 1        1.0                   Allison, Master. Hudson Trevor    male
# 2        1.0                     Allison, Miss. Helen Loraine  female
# 4        1.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6        1.0                Andrews, Miss. Kornelia Theodosia  female
# 7        1.0                           Andrews, Mr. Thomas Jr    male
# ...      ...                                              ...     ...
# 1303     3.0                            Yousseff, Mr. Gerious    male
# 1304     3.0                             Zabour, Miss. Hileni  female
# 1305     3.0                            Zabour, Miss. Thamine  female
# 1307     3.0                              Zakarian, Mr. Ortin    male
# 1308     3.0                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked
# 1      0.9167    1.0    2.0  113781  151.5500  C22 C26        S
# 2      2.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 4     25.0000    1.0    2.0  113781  151.5500  C22 C26        S
# 6     63.0000    1.0    0.0   13502   77.9583       D7        S
# 7     39.0000    0.0    0.0  112050    0.0000      A36        S
# ...       ...    ...    ...     ...       ...      ...      ...
# 1303      NaN    0.0    0.0    2627   14.4583     None        C
# 1304  14.5000    1.0    0.0    2665   14.4542     None        C
# 1305      NaN    1.0    0.0    2665   14.4542     None        C
# 1307  27.0000    0.0    0.0    2670    7.2250     None        C
# 1308  29.0000    0.0    0.0  315082    7.8750     None        S
#
# [1047 rows x 10 columns]

# %%
X_test.head().sort_index()
# Out:
#       pclass                        name     sex   age  sibsp  parch  ticket  \
# 721      3.0            Coleff, Mr. Peju    male  36.0    0.0    0.0  349210
# 1028     3.0         Moran, Miss. Bertha  female   NaN    1.0    0.0  371110
# 1121     3.0    Peter, Master. Michael J    male   NaN    1.0    1.0    2668
# 1155     3.0  Rommetvedt, Mr. Knud Paust    male   NaN    0.0    0.0  312993
# 1251     3.0  Tomlin, Mr. Ernest Portage    male  30.5    0.0    0.0  364499
#
#          fare cabin embarked
# 721    7.4958  None        S
# 1028  24.1500  None        Q
# 1121  22.3583  None        C
# 1155   7.7750  None        S
# 1251   8.0500  None        S

# %%
X_trainTest
# Out:
#       pclass                                             name     sex  \
# 1        1.0                   Allison, Master. Hudson Trevor    male
# 2        1.0                     Allison, Miss. Helen Loraine  female
# 4        1.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6        1.0                Andrews, Miss. Kornelia Theodosia  female
# 7        1.0                           Andrews, Mr. Thomas Jr    male
# ...      ...                                              ...     ...
# 1303     3.0                            Yousseff, Mr. Gerious    male
# 1304     3.0                             Zabour, Miss. Hileni  female
# 1305     3.0                            Zabour, Miss. Thamine  female
# 1307     3.0                              Zakarian, Mr. Ortin    male
# 1308     3.0                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare embarked
# 1      0.9167    1.0    2.0  113781  151.5500        S
# 2      2.0000    1.0    2.0  113781  151.5500        S
# 4     25.0000    1.0    2.0  113781  151.5500        S
# 6     63.0000    1.0    0.0   13502   77.9583        S
# 7     39.0000    0.0    0.0  112050    0.0000        S
# ...       ...    ...    ...     ...       ...      ...
# 1303      NaN    0.0    0.0    2627   14.4583        C
# 1304  14.5000    1.0    0.0    2665   14.4542        C
# 1305      NaN    1.0    0.0    2665   14.4542        C
# 1307  27.0000    0.0    0.0    2670    7.2250        C
# 1308  29.0000    0.0    0.0  315082    7.8750        S
#
# [1047 rows x 9 columns]

# %%
for dataset in [X_trainTest]:
    dataset['family_size'] = dataset['parch'] + dataset['sibsp']
    dataset.drop(['parch','sibsp'], axis=1, inplace=True)
    dataset['is_alone'] = 1
    dataset['is_alone'].loc[dataset['family_size'] > 1] = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 for dataset in [X_trainTest]:
#       2     dataset['family_size'] = dataset['parch'] + dataset['sibsp']
#       3     dataset.drop(['parch','sibsp'], axis=1, inplace=True)
#
# NameError: name 'X_trainTest' is not defined

# %%
X_trainTest
# Out:
#       pclass                                             name     sex  \
# 1        1.0                   Allison, Master. Hudson Trevor    male
# 2        1.0                     Allison, Miss. Helen Loraine  female
# 4        1.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 6        1.0                Andrews, Miss. Kornelia Theodosia  female
# 7        1.0                           Andrews, Mr. Thomas Jr    male
# ...      ...                                              ...     ...
# 1303     3.0                            Yousseff, Mr. Gerious    male
# 1304     3.0                             Zabour, Miss. Hileni  female
# 1305     3.0                            Zabour, Miss. Thamine  female
# 1307     3.0                              Zakarian, Mr. Ortin    male
# 1308     3.0                               Zimmerman, Mr. Leo    male
#
#           age  ticket      fare embarked  family_size  is_alone
# 1      0.9167  113781  151.5500        S          3.0         0
# 2      2.0000  113781  151.5500        S          3.0         0
# 4     25.0000  113781  151.5500        S          3.0         0
# 6     63.0000   13502   77.9583        S          1.0         1
# 7     39.0000  112050    0.0000        S          0.0         1
# ...       ...     ...       ...      ...          ...       ...
# 1303      NaN    2627   14.4583        C          0.0         1
# 1304  14.5000    2665   14.4542        C          1.0         1
# 1305      NaN    2665   14.4542        C          1.0         1
# 1307  27.0000    2670    7.2250        C          0.0         1
# 1308  29.0000  315082    7.8750        S          0.0         1
#
# [1047 rows x 9 columns]

# %%
#Performing the above filtering operations on Original Dataset
for dataset in [X_train]:
    dataset['family_size'] = dataset['parch'] + dataset['sibsp']
    dataset.drop(['parch','sibsp'], axis=1,inplace=True)
    dataset['is_alone'] = 1
    dataset['is_alone'].loc[dataset['family_size'] > 1] = 0
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1756\3428541648.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset['is_alone'].loc[dataset['family_size'] > 1] = 0

# %%
X_train.head(5)
# Out:
#       pclass                                           name     sex   age  \
# 999      3.0              McCarthy, Miss. Catherine 'Katie'  female   NaN
# 392      2.0  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0
# 628      3.0              Andersson, Miss. Sigrid Elisabeth  female  11.0
# 1165     3.0                               Saad, Mr. Khalil    male  25.0
# 604      3.0                    Abelseth, Miss. Karen Marie  female  16.0
#
#              ticket     fare cabin embarked  family_size  is_alone
# 999          383123   7.7500  None        Q          0.0         1
# 392   SC/PARIS 2167  27.7208  None        C          1.0         1
# 628          347082  31.2750  None        S          6.0         0
# 1165           2672   7.2250  None        C          0.0         1
# 604          348125   7.6500  None        S          0.0         1

# %%
X_trainTest['name'].str.split(',',expand=True)[1].str.split(".",expand=True)
# Out:
#             0                                   1     2
# 1      Master                       Hudson Trevor  None
# 2        Miss                       Helen Loraine  None
# 4         Mrs   Hudson J C (Bessie Waldo Daniels)  None
# 6        Miss                  Kornelia Theodosia  None
# 7          Mr                           Thomas Jr  None
# ...       ...                                 ...   ...
# 1303       Mr                             Gerious  None
# 1304     Miss                              Hileni  None
# 1305     Miss                             Thamine  None
# 1307       Mr                               Ortin  None
# 1308       Mr                                 Leo  None
#
# [1047 rows x 3 columns]

# %%
for dataset in [X_trainTest]:
    dataset['title'] = dataset['name'].str.split(',',expand=True)[1].str.split('.',expand=True)[0]
    dataset.drop(['name'], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 for dataset in [X_trainTest]:
#       2     dataset['title'] = dataset['name'].str.split(',',expand=True)[1].str.split('.',expand=True)[0]
#       3     dataset.drop(['name'], axis=1,inplace=True)
#
# NameError: name 'X_trainTest' is not defined

# %%
X_trainTest
# Out:
#       pclass     sex      age  ticket      fare embarked  family_size  \
# 1        1.0    male   0.9167  113781  151.5500        S          3.0
# 2        1.0  female   2.0000  113781  151.5500        S          3.0
# 4        1.0  female  25.0000  113781  151.5500        S          3.0
# 6        1.0  female  63.0000   13502   77.9583        S          1.0
# 7        1.0    male  39.0000  112050    0.0000        S          0.0
# ...      ...     ...      ...     ...       ...      ...          ...
# 1303     3.0    male      NaN    2627   14.4583        C          0.0
# 1304     3.0  female  14.5000    2665   14.4542        C          1.0
# 1305     3.0  female      NaN    2665   14.4542        C          1.0
# 1307     3.0    male  27.0000    2670    7.2250        C          0.0
# 1308     3.0    male  29.0000  315082    7.8750        S          0.0
#
#       is_alone    title
# 1            0   Master
# 2            0     Miss
# 4            0      Mrs
# 6            1     Miss
# 7            1       Mr
# ...        ...      ...
# 1303         1       Mr
# 1304         1     Miss
# 1305         1     Miss
# 1307         1       Mr
# 1308         1       Mr
#
# [1047 rows x 9 columns]

# %%
#Performing the above operations on original Dataset
for dataset in [X_train]:
    dataset['title'] = dataset['name'].str.split(',',expand=True)[1].str.split('.',expand=True)[0]
    dataset.drop(['name'], axis=1,inplace=True)

# %%
X_train.head()
# Out:
#       pclass     sex   age         ticket     fare embarked  family_size  \
# 999      3.0  female   NaN         383123   7.7500        Q          0.0
# 392      2.0  female  24.0  SC/PARIS 2167  27.7208        C          1.0
# 628      3.0  female  11.0         347082  31.2750        S          6.0
# 1165     3.0    male  25.0           2672   7.2250        C          0.0
# 604      3.0  female  16.0         348125   7.6500        S          0.0
#
#       is_alone  title
# 999          1   Miss
# 392          1    Mrs
# 628          0   Miss
# 1165         1     Mr
# 604          1   Miss

# %%
pd.crosstab(X_train['title'],X_train['sex'])
# Out:
# sex            female  male
# title
#  Capt               0     1
#  Col                0     3
#  Don                0     1
#  Dona               1     0
#  Dr                 0     6
#  Major              0     1
#  Master             0    51
#  Miss             210     0
#  Mlle               2     0
#  Mr                 0   606
#  Mrs              156     0
#  Ms                 2     0
#  Rev                0     6
#  the Countess       1     0

# %%
X_trainTest['title'].value_counts()
# Out:
#  Mr              606
#  Miss            210
#  Mrs             156
#  Master           51
#  Dr                6
#  Rev               6
#  Col               3
#  Mlle              2
#  Ms                2
#  Major             1
#  Capt              1
#  Dona              1
#  the Countess      1
#  Don               1
# Name: title, dtype: int64

# %%
X_trainTest.title.loc[X_trainTest.title == 'Miss']
# Out:
# Series([], Name: title, dtype: object)

# %%
#For titles which count less than 10
rare_titles=X_train['title'].value_counts() < 10

# %%
rare_titles
# Out:
#  Mr              False
#  Miss            False
#  Mrs             False
#  Master          False
#  Rev              True
#  Dr               True
#  Col              True
#  Mlle             True
#  Ms               True
#  Major            True
#  Don              True
#  the Countess     True
#  Capt             True
#  Dona             True
# Name: title, dtype: bool

# %%
#Combining titles : Mrs and Miss together to seek survival chances of given Gender:
for dataset in [X_train]:
    dataset.title.loc[dataset.title == "Miss"] = 'Mrs'
    dataset['title'] = dataset.title.apply(lambda x: 'rare' if rare_titles[x] else x)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1756\249189974.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.title.loc[dataset.title == "Miss"] = 'Mrs'

# %%
#Above operation considered changing Miss values to Mrs
#Also considered changing values with < 10 count as 'rare'
X_train.head()
# Out:
#       pclass     sex   age         ticket     fare embarked  family_size  \
# 999      3.0  female   NaN         383123   7.7500        Q          0.0
# 392      2.0  female  24.0  SC/PARIS 2167  27.7208        C          1.0
# 628      3.0  female  11.0         347082  31.2750        S          6.0
# 1165     3.0    male  25.0           2672   7.2250        C          0.0
# 604      3.0  female  16.0         348125   7.6500        S          0.0
#
#       is_alone  title
# 999          1   Miss
# 392          1    Mrs
# 628          0   Miss
# 1165         1     Mr
# 604          1   Miss

# %%
#From Now on, we will Carry out Data imputation : to fill None/Null values.
X_train.dtypes
# Out:
# pclass          float64
# sex            category
# age             float64
# ticket           object
# fare            float64
# embarked       category
# family_size     float64
# is_alone          int64
# title            object
# dtype: object

# %%
X_trainTest.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 X_trainTest.head()
#
# NameError: name 'X_trainTest' is not defined

# %%
X_train.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 X_train.dtypes
#
# NameError: name 'X_train' is not defined

# %%
#Get average age of total passengers:
X_train['age'].mean()
# Out:
# 29.60431587112172

# %%
#Get average age of total passengers:
X_train['family_size'].mean()
# Out:
# 0.8701050620821394

# %%
#Get number of Adults and Children
(X_train['age'] > 18).value_counts()
# Out:
# True     676
# False    371
# Name: age, dtype: int64

# %%
X_train.drop(['cabin'],axis=1,inplace=True)

# %%
y_train
# Out:
# 999     1
# 392     1
# 628     0
# 1165    0
# 604     1
#        ..
# 1290    1
# 1103    0
# 755     0
# 530     0
# 668     0
# Name: survived, Length: 1047, dtype: category
# Categories (2, object): ['0', '1']

# %%
X_train
# Out:
#       pclass                                           name     sex   age  \
# 999      3.0              McCarthy, Miss. Catherine 'Katie'  female   NaN
# 392      2.0  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0
# 628      3.0              Andersson, Miss. Sigrid Elisabeth  female  11.0
# 1165     3.0                               Saad, Mr. Khalil    male  25.0
# 604      3.0                    Abelseth, Miss. Karen Marie  female  16.0
# ...      ...                                            ...     ...   ...
# 1290     3.0               Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1103     3.0                   Panula, Master. Urho Abraham    male   2.0
# 755      3.0                             Davies, Mr. Joseph    male  17.0
# 530      2.0                Pengelly, Mr. Frederick William    male  19.0
# 668      3.0                         Barton, Mr. David John    male  22.0
#
#              ticket     fare embarked  family_size  is_alone
# 999          383123   7.7500        Q          0.0         1
# 392   SC/PARIS 2167  27.7208        C          1.0         1
# 628          347082  31.2750        S          6.0         0
# 1165           2672   7.2250        C          0.0         1
# 604          348125   7.6500        S          0.0         1
# ...             ...      ...      ...          ...       ...
# 1290         363272   7.0000        S          1.0         1
# 1103        3101295  39.6875        S          5.0         0
# 755       A/4 48873   8.0500        S          2.0         0
# 530           28665  10.5000        S          0.0         1
# 668          324669   8.0500        S          0.0         1
#
# [1047 rows x 9 columns]

# %%
pd.concat([X_test,y_test],axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_10764\2442919708.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pd.concat([X_test,y_test],axis=1).mean()
# pclass     2.217557
# age       30.996394
# sibsp      0.557252
# parch      0.381679
# fare      37.801430
# dtype: float64

# %%
 pd.concat([X_test,y_test],axis=1)
# Out:
#       pclass                                               name     sex   age  \
# 1028     3.0                                Moran, Miss. Bertha  female   NaN
# 1121     3.0                           Peter, Master. Michael J    male   NaN
# 1155     3.0                         Rommetvedt, Mr. Knud Paust    male   NaN
# 1251     3.0                         Tomlin, Mr. Ernest Portage    male  30.5
# 721      3.0                                   Coleff, Mr. Peju    male  36.0
# ...      ...                                                ...     ...   ...
# 952      3.0                     Larsson-Rondberg, Mr. Edvard A    male  22.0
# 969      3.0  Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...  female  30.0
# 125      1.0                                   Fry, Mr. Richard    male   NaN
# 836      3.0                      Gustafsson, Mr. Alfred Ossian    male  20.0
# 203      1.0                            Meyer, Mr. Edgar Joseph    male  28.0
#
#       sibsp  parch    ticket     fare cabin embarked survived
# 1028    1.0    0.0    371110  24.1500  None        Q        1
# 1121    1.0    1.0      2668  22.3583  None        C        1
# 1155    0.0    0.0    312993   7.7750  None        S        0
# 1251    0.0    0.0    364499   8.0500  None        S        0
# 721     0.0    0.0    349210   7.4958  None        S        0
# ...     ...    ...       ...      ...   ...      ...      ...
# 952     0.0    0.0    347065   7.7750  None        S        0
# 969     1.0    0.0    349910  15.5500  None        S        0
# 125     0.0    0.0    112058   0.0000  B102        S        0
# 836     0.0    0.0      7534   9.8458  None        S        0
# 203     1.0    0.0  PC 17604  82.1708  None        C        0
#
# [262 rows x 11 columns]

# %%
for dataset in [X_test,y_test]:
    dataset.X_test['survived'] = dataset.y_test['survived']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 2
#       1 for dataset in [X_test,y_test]:
# ----> 2     dataset.X_test['survived'] = dataset.y_test['survived']
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'y_test'

# %%
X_test_sorted = X_test.sort_index()
y_test_sorted = y_test.sort_index()

# %%
X_test_sorted
# Out:
#       pclass                                           name     sex   age  \
# 0        1.0                  Allen, Miss. Elisabeth Walton  female  29.0
# 3        1.0           Allison, Mr. Hudson Joshua Creighton    male  30.0
# 5        1.0                            Anderson, Mr. Harry    male  48.0
# 8        1.0  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female  53.0
# 9        1.0                        Artagaveytia, Mr. Ramon    male  71.0
# ...      ...                                            ...     ...   ...
# 1277     3.0                           Vartanian, Mr. David    male  22.0
# 1284     3.0                              Webber, Mr. James    male   NaN
# 1289     3.0                        Wiklund, Mr. Karl Johan    male  21.0
# 1302     3.0                              Yousif, Mr. Wazli    male   NaN
# 1306     3.0                      Zakarian, Mr. Mapriededer    male  26.5
#
#       sibsp  parch            ticket      fare    cabin embarked
# 0       0.0    0.0             24160  211.3375       B5        S
# 3       1.0    2.0            113781  151.5500  C22 C26        S
# 5       0.0    0.0             19952   26.5500      E12        S
# 8       2.0    0.0             11769   51.4792     C101        S
# 9       0.0    0.0          PC 17609   49.5042     None        C
# ...     ...    ...               ...       ...      ...      ...
# 1277    0.0    0.0              2658    7.2250     None        C
# 1284    0.0    0.0  SOTON/OQ 3101316    8.0500     None        S
# 1289    1.0    0.0           3101266    6.4958     None        S
# 1302    0.0    0.0              2647    7.2250     None        C
# 1306    0.0    0.0              2656    7.2250     None        C
#
# [262 rows x 10 columns]

# %%
combined_TestX =  pd.concat([X_test,y_test],axis=1)

# %%
#Passengers with who 
g_surv = pd.crosstab(combined_TestX['survived'],combined_TestX['sex'])

# %%
g_surv.plot.bar()
# Out:
# <AxesSubplot: xlabel='survived'>

# %%
(pd.crosstab((combined_TestX['age'] <= 18), combined_TestX['survived'])).plot.bar()
# Out:
# <AxesSubplot: xlabel='age'>

# %%
(X_train.groupby(['sex','pclass']).mean()).plot.bar()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1756\984800753.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   (X_train.groupby(['sex','pclass']).mean()).plot.bar()
# <AxesSubplot: xlabel='sex,pclass'>

# %%
X_train['age'].isna().value_counts()
# Out:
# False    838
# True     209
# Name: age, dtype: int64

# %%
num_cols=['age','fare']
num_transformer = Pipeline(steps=[
    ('imputer',KNNImputer(n_neighbors=5)),
    ('scaler',RobustScaler())
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [70], line 2
#       1 num_cols=['age','fare']
# ----> 2 num_transformer = Pipeline(steps=[
#       3     ('imputer',KNNImputer(n_neighbors=5)),
#       4     ('scaler',RobustScaler())
#       5 ])
#
# NameError: name 'Pipeline' is not defined

# %%
combined_TestX['age'].fillna(combined_TestX['age'].mean(), inplace = True)

# %%
combined_TestX['age'].isna().value_counts()
# Out:
# False    262
# Name: age, dtype: int64

# %%
def clf_performance(classifier, model):
    print(model)
    print('Best Score :' + str(classifier.best_score_))
    print('Best Parameters:' + str(classifier.best_params_))

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier

# %%
#random state =1 to control bootstrapping of samples
rf = RandomForestClassifier(random_state = 1)

# %%
param_grid = {
    'n_estimators':[400,450,500,550], #number of trees in forest
    'criterion':['gini','entropy'],
    'bootstrap':[True],
    'max_depth':[15,20,25],
    'max_features':['auto','sqrt',10],
    'min_samples_leaf':[2,3],
    'min_samples_split':[2,3]
}

# %%
clf_rf = GridSearchCV(rf,param_grid=param_grid, cv= 5, verbose = True, n_jobs= -1)

# %%
best_clf_rf = clf_rf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 288 candidates, totalling 1440 fits
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [90], line 1
# ----> 1 best_clf_rf = clf_rf.fit(X_train,y_train)
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\sklearn\model_selection\_search.py:875, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     869     results = self._format_results(
#     870         all_candidate_params, n_splits, all_out, all_more_results
#     871     )
#     873     return results
# --> 875 self._run_search(evaluate_candidates)
#     877 # multimetric is determined here because in the case of a callable
#     878 # self.scoring the return type is only known after calling
#     879 first_test_score = all_out[0]["test_scores"]
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\sklearn\model_selection\_search.py:1379, in GridSearchCV._run_search(self, evaluate_candidates)
#    1377 def _run_search(self, evaluate_candidates):
#    1378     """Search all candidates in param_grid"""
# -> 1379     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\sklearn\model_selection\_search.py:852, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     845 elif len(out) != n_candidates * n_splits:
#     846     raise ValueError(
#     847         "cv.split and cv.get_n_splits returned "
#     848         "inconsistent results. Expected {} "
#     849         "splits, got {}".format(n_splits, len(out) // n_candidates)
#     850     )
# --> 852 _warn_or_raise_about_fit_failures(out, self.error_score)
#     854 # For callable self.scoring, the return type is only know after
#     855 # calling. If the return type is a dictionary, the error scores
#     856 # can now be inserted with the correct key. The type checking
#     857 # of out will be done in `_insert_error_scores`.
#     858 if callable(self.scoring):
#
# File ~\anaconda3\envs\MLStats\lib\site-packages\sklearn\model_selection\_validation.py:367, in _warn_or_raise_about_fit_failures(results, error_score)
#     360 if num_failed_fits == num_fits:
#     361     all_fits_failed_message = (
#     362         f"\nAll the {num_fits} fits failed.\n"
#     363         "It is very likely that your model is misconfigured.\n"
#     364         "You can try to debug the error by setting error_score='raise'.\n\n"
#     365         f"Below are more details about the failures:\n{fit_errors_summary}"
#     366     )
# --> 367     raise ValueError(all_fits_failed_message)
#     369 else:
#     370     some_fits_failed_message = (
#     371         f"\n{num_failed_fits} fits failed out of a total of {num_fits}.\n"
#     372         "The score on these train-test partitions for these parameters"
#    (...)
#     376         f"Below are more details about the failures:\n{fit_errors_summary}"
#     377     )
#
# ValueError:
# All the 1440 fits failed.
# It is very likely that your model is misconfigured.
# You can try to debug the error by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 288 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\ensemble\_forest.py", line 331, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\base.py", line 596, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\utils\validation.py", line 1074, in check_X_y
#     X = check_array(
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\utils\validation.py", line 856, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\pandas\core\generic.py", line 2070, in __array__
#     return np.asarray(self._values, dtype=dtype)
# ValueError: could not convert string to float: 'male'
#
# --------------------------------------------------------------------------------
# 1152 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\ensemble\_forest.py", line 331, in fit
#     X, y = self._validate_data(
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\base.py", line 596, in _validate_data
#     X, y = check_X_y(X, y, **check_params)
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\utils\validation.py", line 1074, in check_X_y
#     X = check_array(
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\sklearn\utils\validation.py", line 856, in check_array
#     array = np.asarray(array, order=order, dtype=dtype)
#   File "C:\Users\Admin\anaconda3\envs\MLStats\lib\site-packages\pandas\core\generic.py", line 2070, in __array__
#     return np.asarray(self._values, dtype=dtype)
# ValueError: could not convert string to float: 'female'

# %%
newX_train = X_train.copy()

# %%
newX_train['sex'].replace(['female','male'],[0,1], inplace=True)

# %%
combined_TestX.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 262 entries, 1028 to 203
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    262 non-null    float64
#  1   name      262 non-null    object
#  2   sex       262 non-null    int32
#  3   age       262 non-null    float64
#  4   sibsp     262 non-null    float64
#  5   parch     262 non-null    float64
#  6   ticket    262 non-null    object
#  7   fare      262 non-null    int32
#  8   embarked  260 non-null    category
# dtypes: category(1), float64(4), int32(2), object(2)
# memory usage: 24.9+ KB

# %%
combined_TestX.drop(['survived'],axis=1, inplace=True)

# %%
combined_TestX['sex'].replace(['female','male'],[0,1], inplace=True)

# %%
combined_TestX['sex'] = combined_TestX['sex'].astype(int)

# %%
combined_TestX.drop(['cabin'],axis=1,inplace=True)

# %%
for dataset in [combined_TestX]:
    dataset['fare'] = dataset['fare'].fillna(0)
    dataset['fare'] = dataset['fare'].astype(int)

# %%
combined_TestX
# Out:
#       pclass                                               name  sex  \
# 1028     3.0                                Moran, Miss. Bertha    0
# 1121     3.0                           Peter, Master. Michael J    1
# 1155     3.0                         Rommetvedt, Mr. Knud Paust    1
# 1251     3.0                         Tomlin, Mr. Ernest Portage    1
# 721      3.0                                   Coleff, Mr. Peju    1
# ...      ...                                                ...  ...
# 952      3.0                     Larsson-Rondberg, Mr. Edvard A    1
# 969      3.0  Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...    0
# 125      1.0                                   Fry, Mr. Richard    1
# 836      3.0                      Gustafsson, Mr. Alfred Ossian    1
# 203      1.0                            Meyer, Mr. Edgar Joseph    1
#
#             age  sibsp  parch    ticket  fare embarked
# 1028  30.996394    1.0    0.0    371110    24        Q
# 1121  30.996394    1.0    1.0      2668    22        C
# 1155  30.996394    0.0    0.0    312993     7        S
# 1251  30.500000    0.0    0.0    364499     8        S
# 721   36.000000    0.0    0.0    349210     7        S
# ...         ...    ...    ...       ...   ...      ...
# 952   22.000000    0.0    0.0    347065     7        S
# 969   30.000000    1.0    0.0    349910    15        S
# 125   30.996394    0.0    0.0    112058     0        S
# 836   20.000000    0.0    0.0      7534     9        S
# 203   28.000000    1.0    0.0  PC 17604    82        C
#
# [262 rows x 9 columns]

# %%
combined_TestX['name'].str.split(',',expand=True)[1].str.split('.',expand=True)[0]
# Out:
# 1028       Miss
# 1121     Master
# 1155         Mr
# 1251         Mr
# 721          Mr
#          ...
# 952          Mr
# 969         Mrs
# 125          Mr
# 836          Mr
# 203          Mr
# Name: 0, Length: 262, dtype: object

# %%
for dataset in [combined_TestX]:
    dataset['title'] = dataset['name'].str.split(',',expand=True)[1].str.split('.',expand=True)[0]
    dataset.drop(['name'], axis=1,inplace=True)

# %%
rare_titles=combined_TestX['title'].value_counts() < 10

# %%
for dataset in [combined_TestX]:
    dataset.title.loc[dataset.title == "Miss"] = 'Mrs'
    dataset['title'] = dataset.title.apply(lambda x: 'rare' if rare_titles[x] else x)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_1756\3154953666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.title.loc[dataset.title == "Miss"] = 'Mrs'

# %%
combined_TestX['title'].value_counts()
# Out:
#  Mr        151
#  Miss       50
#  Mrs        41
#  Master     10
# rare        10
# Name: title, dtype: int64

# %%
titles = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "rare": 5}

# %%
cmbTest = combined_TestX.copy()

# %%
for ds in [cmbTest]:
    ds['title'] = ds['title'].map(titles)

# %%
cmbTest
# Out:
#       pclass  sex        age  sibsp  parch    ticket  fare embarked    title
# 1028     3.0    0  30.996394    1.0    0.0    371110    24        Q     Miss
# 1121     3.0    1  30.996394    1.0    1.0      2668    22        C   Master
# 1155     3.0    1  30.996394    0.0    0.0    312993     7        S       Mr
# 1251     3.0    1  30.500000    0.0    0.0    364499     8        S       Mr
# 721      3.0    1  36.000000    0.0    0.0    349210     7        S       Mr
# ...      ...  ...        ...    ...    ...       ...   ...      ...      ...
# 952      3.0    1  22.000000    0.0    0.0    347065     7        S       Mr
# 969      3.0    0  30.000000    1.0    0.0    349910    15        S      Mrs
# 125      1.0    1  30.996394    0.0    0.0    112058     0        S       Mr
# 836      3.0    1  20.000000    0.0    0.0      7534     9        S       Mr
# 203      1.0    1  28.000000    1.0    0.0  PC 17604    82        C       Mr
#
# [262 rows x 9 columns]
